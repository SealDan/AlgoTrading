# %% [markdown]
# 1.Write a Python print statement that shows a message saying, "Starting the trading session."

# %%
#Write your code here
print("Starting the trading session.")
# Out:
# Starting the trading session.

# %% [markdown]
# 2.Create a variable stock_price that stores the current price of a stock as a floating-point number.

# %%
#Write your code here
stock_price = 270.01

# %% [markdown]
# 3.Assign the symbol AAPL to a variable named stock_symbol.

# %%
#Write your code here
stock_symbol = "AAPL"

# %% [markdown]
# 4.Add a comment explaining that the following code will initialize a trading balance variable with 10000.

# %%
#Write your code here
'''
The following code will initialize a trading balance variable with 10000!
'''
initial_price = 10000

# %% [markdown]
# 5.Identify and fix the syntax error in the following code snippet:
#    total_return = final_price - initial_price
#    print(total_return)

# %%
#Write your code here
final_price = 23000
total_return = final_price - initial_price
print(total_return)
# Out:
# 13000

# %% [markdown]
# 6.Write a program that asks the user for the quantity of a stock to buy and prints "Buying X shares," where X is the input quantity.

# %%
#Write your code here
input_quantity = input("Quanity of stocks to buy: ")
print("Buying", input_quantity, "shares!")
# Out:
# Quanity of stocks to buy:  1000
# Buying 1000 shares!

# %% [markdown]
# 7.Convert a string variable price_str holding the value "89.50" into a floating-point number.

# %%
#Write your code here
price_str = "89.50"
price_float = float(price_str)
print(type(price_str))
print(type(price_float))
# Out:
# <class 'str'>
# <class 'float'>

# %% [markdown]
# 8.Define a list literal containing the stock symbols "AAPL", "TSLA", and "GOOGL".

# %%
#Write your code here
stock_symbols = ["AAPL", "TSLA", "GOOGL"]
print(stock_symbols)
print(type(stock_symbols))
# Out:
# ['AAPL', 'TSLA', 'GOOGL']
# <class 'list'>

# %% [markdown]
# 9.Write a print statement that outputs "Stock XYZ is trading at $PRICE", where XYZ is a variable symbol, and PRICE is a floating-point variable price.

# %%
#Write your code here
var_sym = "AAPL"
price = 1.4
print("Stock", var_sym, "is trading at $" + str(price))
# Out:
# Stock AAPL is trading at $1.4

# %% [markdown]
# 10.Write a Python Program print_trade_summary(symbol, quantity, price) that accepts a stock symbol, the number of shares, and the price per share. It should print out a formatted summary of the total trade cost.

# %%
#Write your code here
def print_trade_summary (symbol, quantity, price):
    print("Stock symbol:", symbol)
    print("Number of shares:", quantity)
    print("Price per share:", price)

print_trade_summary("AAPL", 1000, 270.1)
# Out:
# Stock symbol: AAPL
# Number of shares: 1000
# Price per share: 270.1

# %% [markdown]
# **11.** Calculate the Daily Return on Investment (ROI)
#
# **Objective:** Prompt the user to enter the purchase price and the selling price of a stock, and calculate the ROI.

# %%
#Write your code here
purchase_price = float(input("Purchase Price:"))
sell_price = float(input("Selling Price:"))
ROI = (sell_price - purchase_price) / purchase_price * 100
print("Your ROI on that stock is", str(ROI)+"%")
# Out:
# Purchase Price: 100
# Selling Price: 120
# Your ROI on that stock is 20.0%

# %% [markdown]
# **12.** Determine the Average Price from User Inputs
#
# **Objective:** Ask the user to input three different prices of a stock throughout the day and compute the average.

# %%
#Write your code here
print("Input three different prices of a stock throughout the day!")
price1 = input("Price 1: ")
price2 = input("Price 2: ")
price3 = input("Price 3: ")
avg = (float(price1) + float(price2) + float(price3)) / 3
print("The average of all three stock prices of today is", avg)
# Out:
# Input three different prices of a stock throughout the day!
# Price 1:  1
# Price 2:  5
# Price 3:  10
# The average of all three stock prices of today is 5.333333333333333

# %% [markdown]
# **13.** Compare Two Stock Prices
#
# **Objective:** Ask the user for the prices of two stocks and print which one is higher.

# %%
#Write your code here
stock1 = float(input("Stock 1 Price: "))
stock2 = float(input("Stock 2 Price: "))
if(stock1 > stock2):
    print("Stock 1 is higher")
else:
    print("Stock 2 is higher")
# Out:
# Stock 1 Price:  10
# Stock 2 Price:  2
# Stock 1 is higher

# %% [markdown]
# **14.** Break-Even Price Calculator
#
# **Objective:** Calculate the break-even price after buying a stock and spending money on fees.

# %%
#Write your code here
def breakEven_calc(quantity, price, fees):
    return ((quantity*price) + fees) / quantity

print("The Break-Even Price after buying the stock is", breakEven_calc(1000, 10, 50))
# Out:
# The Break-Even Price after buying the stock is 10.05

# %% [markdown]
# **15.** Display Stock Price Change
#
# **Objective:** Ask the user to enter yesterday's and today's stock prices, then print the change in price.

# %%
#Write your code here
def change_price(yesterday, today):
    return today - yesterday

print("The change in price of the stock is", change_price(8, 10))
# Out:
# The change in price of the stock is 2

# %% [markdown]
# **16.** Calculate Required Margin
#
# **Objective:** Calculate the required margin for a trade based on user inputs for trade size and margin rate.

# %%
#Write your code here
trade_size = input("Trade size: ")
margin_rate = input("Margin rate: ")

required_margin = float(trade_size) * float(margin_rate)
print("The required margin is", required_margin)
# Out:
# Trade size:  1000
# Margin rate:  0.05
# The required margin is 50.0

# %% [markdown]
# **17.** Convert Currency from User Input
#
# **Objective:** Ask the user for an amount in USD and a conversion rate, then convert it to another currency.

# %%
#Write your code here
usd = input("An amount in USD to be converted to IDR: ")
conversion = float(usd) * 16701.60
print("The conversion rate of the USD amount is IDR", round(conversion))
# Out:
# An amount in USD to be converted to IDR:  1000
# The conversion rate of the USD amount is IDR 16701600

# %% [markdown]
# **18.** Calculate the Weighted Average Price
#
# **Objective:** Calculate the weighted average price based on user inputs for different prices and their respective weights.

# %%
#Write your code here
numOfPrices = int(input("How many items?"))
PQ = 0
quantity = 0
index = 0

while numOfPrices > 0:
    cost = input("Cost per share:")
    amount = input("How many shares:")
    PQ += float(cost)*float(amount)
    quantity += float(amount)
    numOfPrices -= 1

WAP = PQ/quantity
print("The Weighted Average Price of all the stocks are:", WAP)
# Out:
# How many items? 3
# Cost per share: 5
# How many shares: 10
# Cost per share: 8
# How many shares: 20
# Cost per share: 7
# How many shares: 30
# The Weighted Average Price of all the stocks are: 7.0

# %% [markdown]
# **19.** User Input to Adjust Stock Quantity
#
# **Objective:** Prompt the user for the current number of stocks, how many to buy, and how many to sell, then calculate the new total.

# %%
#Write your code here
current = float(input("Current number of stocks:"))
buy = float(input("How many to buy:"))
sell = float(input("How many to sell:"))

new_total = current + buy - sell

print("Your new adjusted stock quantity is", new_total)
# Out:
# Current number of stocks: 10
# How many to buy: 100
# How many to sell: 30
# Your new adjusted stock quantity is 80.0

# %% [markdown]
# ### Python Mini Project 1 :
#
# Scenario: Stock Data Entry and Analysis Tool
#
# **Objective:**
# Create a Python script that  will involve taking manual input for stock prices over a week and will calculate the average price. It should also demonstrate variable declaration, user input, and basic arithmetic using Python types.

# %%
day = 1
price = 0
while day <= 7:
    price += float(input("Day " + str(day)+ " Price:"))
    day += 1

avg_price = price / 7

print("The average price of the stock throughout the week is", avg_price)
# Out:
# Day 1 Price: 10
# Day 2 Price: 5
# Day 3 Price: 2
# Day 4 Price: 5
# Day 5 Price: 100
# Day 6 Price: 20
# Day 7 Price: 60
# The average price of the stock throughout the week is 28.857142857142858
